# %%
import pandas as pd
adult_census = pd.read_csv("scikit-learn-mooc/datasets/adult-census-numeric.csv")

# %%
target_name = "class"
target = adult_census[target_name]
data = adult_census.drop(columns=target_name)

# %%
numerical_columns = ["age", "capital-gain", "capital-loss", "hours-per-week"]

data_numeric = data[numerical_columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data,
    target,
    test_size=0.1,
    random_state=42
)

X_train, X_test, y_train, y_test
# Out:
# (       age  capital-gain  capital-loss  hours-per-week
#  20018   24             0             0              20
#  22254   63          7298             0              40
#  17660   38             0             0              52
#  30741   19             0             0              35
#  37936   27             0             0              40
#  ...    ...           ...           ...             ...
#  6265    50             0             0              50
#  11284   46             0             0              60
#  38158   35             0             0              30
#  860     48             0             0              40
#  15795   52             0             0              40
#
#  [35165 rows x 4 columns],
#         age  capital-gain  capital-loss  hours-per-week
#  37272   58          7298             0              60
#  1912    28             0             0              40
#  27220   54             0             0              40
#  33245   35             0             0              38
#  27732   45             0             0              40
#  ...    ...           ...           ...             ...
#  37096   51         27828             0              40
#  24801   42             0             0              33
#  24683   40             0             0              50
#  15350   46             0             0              41
#  30768   24             0             0              40
#
#  [3908 rows x 4 columns],
#  20018     <=50K
#  22254      >50K
#  17660     <=50K
#  30741     <=50K
#  37936     <=50K
#            ...
#  6265      <=50K
#  11284     <=50K
#  38158     <=50K
#  860       <=50K
#  15795     <=50K
#  Name: class, Length: 35165, dtype: object,
#  37272      >50K
#  1912      <=50K
#  27220     <=50K
#  33245     <=50K
#  27732     <=50K
#            ...
#  37096      >50K
#  24801     <=50K
#  24683     <=50K
#  15350      >50K
#  30768     <=50K
#  Name: class, Length: 3908, dtype: object)

# %%
from sklearn.dummy import DummyClassifier

dummy50k = DummyClassifier(strategy="constant", constant=" >50K")
dummy50k.fit(X_train, y_train)

accuracy50k = dummy50k.score(X_test, y_test)
accuracy50k
# Out:
# 0.25358239508700103

# %%
target.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
target = target.str.strip()
