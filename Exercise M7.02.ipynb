# %%
import pandas as pd

blood_transfusion = pd.read_csv("scikit-learn-mooc/datasets/blood_transfusion.csv")
data = blood_transfusion.drop(columns="Class")
target = blood_transfusion["Class"]

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(random_state=0)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

scores= cross_val_score(tree, data, target, cv=cv, scoring="accuracy")
scores
# Out:
# array([0.73333333, 0.76666667, 0.65333333, 0.73154362, 0.7114094 ])

# %%
from sklearn.metrics import make_scorer, precision_score

precisionscorer = make_scorer(precision_score, pos_label="donated")
precisionscorer
# Out:
# make_scorer(precision_score, response_method='predict', pos_label=donated)
